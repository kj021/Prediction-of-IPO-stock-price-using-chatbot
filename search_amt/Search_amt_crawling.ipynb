# %%
#from PyNaver import Datalab
import pandas as pd
import urllib.request
from datetime import datetime, timedelta
import json
import sys
import os
import warnings
import re
warnings.filterwarnings(action='ignore')

today = str(datetime.now().date())
recent_8_days = str(datetime.now().date() - timedelta(weeks=1,days=1))
regex = '\(.*\)|\s-\s'

# %%
ratio_df = pd.read_csv('sub_day_search.csv')
recent_search = pd.read_csv('recent_search.csv')

# %%
ratio_df
# Out:
#            검색량      기업명                   날짜
# 0          NaN      NaN                  NaN
# 1    100.00000  에이치와이티씨           2022-07-29
# 2     11.64390  에이치와이티씨           2022-07-30
# 3    100.00000      새빗켐           2022-07-27
# 4     44.77778      새빗켐           2022-07-28
# ..         ...      ...                  ...
# 994   51.95530    한솔씨앤피           2016-01-21
# 995  100.00000   모두투어리츠  2016-09-02 00:00:00
# 996   25.78947   모두투어리츠  2016-09-03 00:00:00
# 997  100.00000   신한알파리츠  2018-07-27 00:00:00
# 998   22.83345   신한알파리츠  2018-07-28 00:00:00
#
# [999 rows x 3 columns]

# %%
days = pd.read_csv('after_prepros_get_score.csv')
#days = days[~days['기업명'].str.contains('스팩')]
#days["청약일"] = days["청약일"].str.replace(pat=r'[^\w]', repl=r'', regex=True)
days['subs_day'] = pd.to_datetime(days['subs_day'])
#days = days.reset_index()
#days.drop(['수요예측일','Unnamed: 0','index'], axis = 1,inplace = True)

for i in range(len(days['cor_name'])):
    days['cor_name'][i] = re.sub(regex,'',days['cor_name'][i])
days = days[days['listed_date'] > 20160102]
days = days[~days['cor_name'].isin(['코썬바이오'])]
days.reset_index(drop=True,inplace=True)

# %%
days
# Out:
#      Unnamed: 0    cor_name  cor_rate  obligation  market_type  listed_date  \
# 0             0     에이치와이티씨   1480.78        6.08            0     20220809
# 1             1         새빗켐   1670.90       37.70            0     20220804
# 2             2     수산인더스트리    130.37       18.94            1     20220801
# 3             3     에이프릴바이오     14.43       10.66            0     20220728
# 4             4      아이씨에이치     57.28       12.47            0     20220729
# ..          ...         ...       ...         ...          ...          ...
# 464         465   제이에스코퍼레이션    433.60       35.90            1     20160204
# 465         466        아이엠텍    112.30       25.00            0     20160203
# 466         467  차이나크리스탈신소재     36.30        0.90            0     20160128
# 467         468       유니트론텍    455.80       21.70            0     20160202
# 468         469       한솔씨앤피    136.97        5.97            0     20160127
#
#      offer_price  sicho_p  profit_percent      sales  ...  shares_to_pub  \
# 0          15000    14700           -2.00   35745.00  ...           1.00
# 1          35000    70000          100.00   33389.00  ...           0.84
# 2          35000    33000           -5.71  294111.00  ...           0.75
# 3          16000    19500           21.88  153762.78  ...           1.00
# 4          34000    30600          -10.00   24167.00  ...           0.88
# ..           ...      ...             ...        ...  ...            ...
# 464        23000    39100           70.00  162608.00  ...           1.00
# 465         7500     8500           13.33   46553.00  ...           1.00
# 466         3000     4000           33.33  144312.06  ...           1.00
# 467        14000    25300           80.71   86379.00  ...           1.00
# 468        13000    18950           45.77   50873.00  ...           1.00
#
#      sub_rate  pre_demand_day   subs_day l_exp_offer_price  h_exp_offer_price  \
# 0      432.58      2022-07-21 2022-07-29             13000              15000
# 1     1724.96      2022-07-20 2022-07-27             25000              30000
# 2        3.40      2022-07-14 2022-07-21             35000              43100
# 3        4.76      2022-07-13 2022-07-20             20000              23000
# 4        2.51      2022-07-13 2022-07-20             34000              44000
# ..        ...             ...        ...               ...                ...
# 464    477.76      2016-01-20 2016-01-27             19000              23000
# 465    138.90      2016-01-20 2016-01-27              6500               7500
# 466    179.54      2016-01-14 2016-01-22              2900               4200
# 467   1112.76      2016-01-14 2016-01-22             12300              14000
# 468    789.84      2016-01-13 2016-01-20             13000              16800
#
#     score  nasdaq_score  range  Quater_per
# 0    0.35        -0.001   1037       0.600
# 1    0.42         0.026   1036       0.600
# 2    0.45         0.019   1035       0.600
# 3    0.62         0.041   1032       0.600
# 4    0.46         0.011   1034       0.600
# ..    ...           ...    ...         ...
# 464  0.37        -0.003    562       0.282
# 465  0.56        -0.022    561       0.282
# 466  0.30        -0.022    559       0.282
# 467  0.26         0.001    560       0.282
# 468  0.22         0.011    558       0.282
#
# [469 rows x 21 columns]

# %%
class NaverDataLabOpenAPI():
    """
    네이버 데이터랩 오픈 API 컨트롤러 클래스
    """
    def __init__(self, client_id, client_secret):
        """
        인증키 설정 및 검색어 그룹 초기화
        """
        self.client_id = client_id
        self.client_secret = client_secret
        self.keywordGroups = []
        self.url = "https://openapi.naver.com/v1/datalab/search"
    def add_keyword_groups(self, group_dict):
        """
        검색어 그룹 추가
        """
        keyword_gorup = {
            'groupName': group_dict['groupName'],
            'keywords': group_dict['keywords']
        }
        
        self.keywordGroups.append(keyword_gorup)
        #print(f">>> Num of keywordGroups: {len(self.keywordGroups)}")
        
    def get_data(self, startDate, endDate, timeUnit, device, ages, gender):
        """
        요청 결과 반환
        timeUnit - 'date', 'week', 'month'
        device - None, 'pc', 'mo'
        ages = [], ['1' ~ '11']
        gender = None, 'm', 'f'
        """
        # Request body
        body = json.dumps({
            "startDate": startDate,
            "endDate": endDate,
            "timeUnit": timeUnit,
            "keywordGroups": self.keywordGroups,
            "device": device,
            "ages": ages,
            "gender": gender
        }, ensure_ascii=False)
        
        # Results
        request = urllib.request.Request(self.url)
        request.add_header("X-Naver-Client-Id",self.client_id)
        request.add_header("X-Naver-Client-Secret",self.client_secret)
        request.add_header("Content-Type","application/json")
        response = urllib.request.urlopen(request, data=body.encode("utf-8"))
        rescode = response.getcode()
        if(rescode==200):
            # Json Result
            result = json.loads(response.read())
            
            df = pd.DataFrame(result['results'][0]['data'])[['period']]
            for i in range(len(self.keywordGroups)):
                #df['period'] = df.apply(lambda r: [df['period'].values], axis=1, result_type='expand')
                tmp = pd.DataFrame(result['results'][i]['data'])
                tmp = tmp.rename(columns={'ratio': result['results'][i]['title']})
                df = pd.merge(df, tmp, how='left', on=['period'])
            self.df = df.rename(columns={'period': '날짜'})
            self.df['날짜'] = pd.to_datetime(self.df['날짜'])
            
        else:
            print("Error Code:" + rescode)
            
        return self.df

# %%
#상장일 2일동안의 검색량 
today = str(datetime.now().date())
recent_8_days = str(datetime.now().date() - timedelta(weeks=1,days=1))
# API 인증 정보 설정
client_id = "IasLV39qud8JnmvpzcB0"
client_secret = "1Cax7mYUKK"

for i in range(len(days['subs_day'])):
    if days['cor_name'][i] not in ratio_df['기업명'].values:
        name = days['cor_name'][i]
        sub_date = str(days['subs_day'][i].date())
        day_after = str(days['subs_day'][i].date() + timedelta(days=1))
    else:
        continue
        
    keyword_group_set = {
    'keyword_group_1': {'groupName': '검색량', 'keywords': [name]}
                    }
    # 요청 파라미터 설정
    startDate = sub_date
    endDate = day_after
    timeUnit = 'date'
    device = ''
    ages = []
    gender = ''

# 데이터 프레임 정의
    naver = NaverDataLabOpenAPI(client_id=client_id, client_secret=client_secret)

    naver.add_keyword_groups(keyword_group_set['keyword_group_1'])

    df = naver.get_data(startDate, endDate, timeUnit, device, ages, gender)
    df['cor_name'] = name
    ratio_df = pd.concat([ratio_df,df])
ratio_df
# Out:
#            검색량      기업명                   날짜
# 0          NaN      NaN                  NaN
# 1    100.00000  에이치와이티씨           2022-07-29
# 2     11.64390  에이치와이티씨           2022-07-30
# 3    100.00000      새빗켐           2022-07-27
# 4     44.77778      새빗켐           2022-07-28
# ..         ...      ...                  ...
# 994   51.95530    한솔씨앤피           2016-01-21
# 995  100.00000   모두투어리츠  2016-09-02 00:00:00
# 996   25.78947   모두투어리츠  2016-09-03 00:00:00
# 997  100.00000   신한알파리츠  2018-07-27 00:00:00
# 998   22.83345   신한알파리츠  2018-07-28 00:00:00
#
# [999 rows x 3 columns]

# %%
#최근 8일동안 검색량 
client_id = 'IasLV39qud8JnmvpzcB0'
client_secret = '1Cax7mYUKK'
for i in range(len(days['subs_day'])):
    if days['cor_name'][i] not in ratio_df['기업명'].values:
        name = days['cor_name'][i]
    else:
        continue
    url = "https://openapi.naver.com/v1/datalab/search"
    body = "{\"startDate\":\""+recent_8_days+"\",\"endDate\":\""+today+"\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\""+name+"\",\"keywords\":[\""+name+"\"]}]}";
    requested = urllib.request.Request(url)
    requested.add_header("X-Naver-Client-Id", client_id)
    requested.add_header("X-Naver-Client-Secret", client_secret)
    requested.add_header("Content-Type", "application/json")
    response = urllib.request.urlopen(requested, data=body.encode("utf-8"))
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        output_data = response_body.decode('utf-8')
    else:
        print('Error code:'+ rescode)
        continue


    result = json.loads(output_data)
    
    date = [a['period'] for a in result['results'][0]['data']]
    corp_ratio = [a['ratio'] for a in result['results'][0]['data']]

    ratio = pd.DataFrame({'date':date, 
                  '기업검색량':corp_ratio,
                '기업명':name})
    recent_search = pd.concat([recent_search,ratio])
recent_search
# Out:
#       Unnamed: 0        date      기업검색량      기업명
# 0              0         NaN        NaN      NaN
# 1              0  2022-07-29  100.00000  에이치와이티씨
# 2              1  2022-07-30   11.64390  에이치와이티씨
# 3              2  2022-07-31    7.62675  에이치와이티씨
# 4              3  2022-08-01   24.97618  에이치와이티씨
# ...          ...         ...        ...      ...
# 5999           2  2022-07-31   49.02723      케이프
# 6000           3  2022-08-01   96.30350      케이프
# 6001           4  2022-08-02   99.80544      케이프
# 6002           5  2022-08-03  100.00000      케이프
# 6003           6  2022-08-04   88.91050      케이프
#
# [6004 rows x 4 columns]

# %%
ratio_df.to_csv('sub_day_search.csv',index=False)
recent_search.to_csv('recent_search.csv', index=False)

# %%
#ratio_df.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],axis=1,inplace=True)
sub_day_search = ratio_df.groupby('기업명').mean()
sub_day_search.rename(columns={'검색량':'청약일검색량'},inplace=True)
sub_day_search
# Out:
#               청약일검색량
# 기업명
# ING생명보험    57.449205
# LG에너지솔루션   85.464685
# NH올원리츠     57.859765
# SK리츠       63.899235
# SK바이오사이언스  74.984995
# ...              ...
# 현대중공업      73.482235
# 호전실업       60.733840
# 화승엔터프라이즈   61.744120
# 휴네시온       70.359845
# 힘스         78.683875
#
# [494 rows x 1 columns]

# %%
sub_day_search = ratio_df.groupby('기업명').mean()
#sub_day_search.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],axis=1,inplace=True)
sub_day_search.rename(columns={'검색량':'청약일검색량'},inplace=True)
sub_day_search
# Out:
#               청약일검색량
# 기업명
# ING생명보험    57.449205
# LG에너지솔루션   85.464685
# NH올원리츠     57.859765
# SK리츠       63.899235
# SK바이오사이언스  74.984995
# ...              ...
# 현대중공업      73.482235
# 호전실업       60.733840
# 화승엔터프라이즈   61.744120
# 휴네시온       70.359845
# 힘스         78.683875
#
# [494 rows x 1 columns]

# %%
recent_search = recent_search.groupby('기업명').median()
#recent_search.drop(['Unnamed: 0'],axis=1,inplace=True)
recent_search.rename(columns={'기업검색량':'최근일주일검색량'},inplace=True)
recent_search
# Out:
#         Unnamed: 0  최근일주일검색량
# 기업명
# BGF리테일         3.0  65.37931
# CJ헬로비전         3.0  73.84341
# GKL            3.0  77.66393
# GMB코리아         3.0  58.44155
# GS리테일          3.0  48.65889
# ...            ...       ...
# 휴비스            3.0  95.90973
# 휴젤             3.0  80.56253
# 흥국             3.0  94.04761
# 흥국에프엔비         3.0  55.03838
# 힘스             3.0  70.82228
#
# [892 rows x 2 columns]

# %%
merged = pd.merge(sub_day_search,recent_search,how='left',on='기업명')
merged.drop(['Unnamed: 0'],axis=1,inplace=True)
merged.reset_index(inplace=True)
merged
# Out:
#            기업명     청약일검색량   최근일주일검색량
# 0      ING생명보험  57.449205  100.00000
# 1     LG에너지솔루션  85.464685   79.98288
# 2       NH올원리츠  57.859765   72.54098
# 3         SK리츠  63.899235   69.37922
# 4    SK바이오사이언스  74.984995   75.06483
# ..         ...        ...        ...
# 489      현대중공업  73.482235   74.68610
# 490       호전실업  60.733840   77.94117
# 491   화승엔터프라이즈  61.744120   91.08635
# 492       휴네시온  70.359845   76.57992
# 493         힘스  78.683875   70.82228
#
# [494 rows x 3 columns]

# %%
import math
score_list = []
for i in range(len(merged['청약일검색량'])):
    sub_search_amt = round(merged['청약일검색량'][i],3)
    weekly_search_amt = round(merged['최근일주일검색량'][i],3)
    score = math.log10(sub_search_amt) - math.log10(weekly_search_amt)
    score_list.append(score)
merged = merged.assign(비정상검색량지수 = score_list)
merged['비정상검색량지수'] = round(merged['비정상검색량지수'],3)
merged = merged.dropna(axis=0).reset_index(drop=True)
merged.drop(['청약일검색량','최근일주일검색량'], axis = 1,inplace = True)

# %%
merged.columns = ['cor_name','search_amt']

# %%
total_df = pd.read_csv('Column1.csv')
total_df.drop(['Unnamed: 0','Ofc'], axis = 1,inplace = True)
total_df
# Out:
#          Com     Sal    Pro   Sec    Crate     Rate    Obr   Tre  Sco  Sum  \
# 0    에이치피에스피   61174  17658  1.00  1159.05  1511.36  42.54  0.75    3   28
# 1      영창케미칼   60760   2506  0.83   682.13  1616.27   5.92  0.67   12   45
# 2       넥스트칩   10383 -13496  1.00  1727.38  1623.41  11.58  1.00    4   56
# 3     위니아에이드  418527  24895  1.00   111.26   955.00   1.39  0.88    0   59
# 4       레이저쎌    3879  -7665  1.00  1845.11  1442.95  12.43  0.89    2   54
# ..       ...     ...    ...   ...      ...      ...    ...   ...  ...  ...
# 386   데브시스터즈   61303  22326  1.00   285.28   651.66  29.98  1.00   -6   49
# 387     신화콘텍   51059   6446  1.00    99.30   441.99  10.37  0.67    5   24
# 388    덕신하우징  104434  11718  1.00   899.07   650.72  59.86  0.83   12   41
# 389    창해에탄올   69032  14887  1.00   675.79   578.20  59.50  0.80    6   38
# 390     윈하이텍   57400   7122  1.00   589.58   444.10  55.60  0.75   12   45
#
#        Tos  Mat       Lda    Pre    Pop   Hpol   Hpoh    Clp    Beg   Clp.1
# 0    0.107    0  20220715  52700  25000  23000  25000  43250  50000  100.00
# 1    0.267    0  20220714  14250  18600  15000  18600  16450  18400   -1.08
# 2    0.071    0  20220701  12000  13000   9900  11600  14300  17150   31.92
# 3    0.000    0  20220623   9330  16200  14200  16200  11000  14600   -9.88
# 4    0.037    0  20220624  12400  16000  12000  14000  17350  20600   28.75
# ..     ...  ...       ...    ...    ...    ...    ...    ...    ...     ...
# 386 -0.122    0  20141006      -  53000  43000  50000  61000  71000   33.96
# 387  0.208    0  20140808      -   9100   8100   9100   7100   8190  -10.00
# 388  0.293    0  20140801      -  13000   9600  11000  20950  21650   66.54
# 389  0.158    0  20140730      -   8300   6000   6900  14600  16600  100.00
# 390  0.267    0  20140725      -   8300   6600   7500  15250  13300   60.24
#
# [391 rows x 20 columns]

# %%
total_df.columns = ['cor_name','sales','profit','shares_to_pub','sub_rate',
'cor_rate','obligation','trend','score','sum','t_score','market_type','listed_date',
'current_price','offer_price','h_exp_offer_price','l_exp_offer_price','target',
'st_price','end_price']

# %%
total_df = pd.merge(total_df,merged,how='left',on='cor_name')
total_df
# Out:
#     cor_name   sales  profit  shares_to_pub  sub_rate  cor_rate  obligation  \
# 0    에이치피에스피   61174   17658           1.00   1159.05   1511.36       42.54
# 1      영창케미칼   60760    2506           0.83    682.13   1616.27        5.92
# 2       넥스트칩   10383  -13496           1.00   1727.38   1623.41       11.58
# 3     위니아에이드  418527   24895           1.00    111.26    955.00        1.39
# 4       레이저쎌    3879   -7665           1.00   1845.11   1442.95       12.43
# ..       ...     ...     ...            ...       ...       ...         ...
# 386   데브시스터즈   61303   22326           1.00    285.28    651.66       29.98
# 387     신화콘텍   51059    6446           1.00     99.30    441.99       10.37
# 388    덕신하우징  104434   11718           1.00    899.07    650.72       59.86
# 389    창해에탄올   69032   14887           1.00    675.79    578.20       59.50
# 390     윈하이텍   57400    7122           1.00    589.58    444.10       55.60
#
#      trend  score  sum  ...  market_type  listed_date  current_price  \
# 0     0.75      3   28  ...            0     20220715          52700
# 1     0.67     12   45  ...            0     20220714          14250
# 2     1.00      4   56  ...            0     20220701          12000
# 3     0.88      0   59  ...            0     20220623           9330
# 4     0.89      2   54  ...            0     20220624          12400
# ..     ...    ...  ...  ...          ...          ...            ...
# 386   1.00     -6   49  ...            0     20141006              -
# 387   0.67      5   24  ...            0     20140808              -
# 388   0.83     12   41  ...            0     20140801              -
# 389   0.80      6   38  ...            0     20140730              -
# 390   0.75     12   45  ...            0     20140725              -
#
#     offer_price  h_exp_offer_price  l_exp_offer_price  target st_price  \
# 0         25000              23000              25000   43250    50000
# 1         18600              15000              18600   16450    18400
# 2         13000               9900              11600   14300    17150
# 3         16200              14200              16200   11000    14600
# 4         16000              12000              14000   17350    20600
# ..          ...                ...                ...     ...      ...
# 386       53000              43000              50000   61000    71000
# 387        9100               8100               9100    7100     8190
# 388       13000               9600              11000   20950    21650
# 389        8300               6000               6900   14600    16600
# 390        8300               6600               7500   15250    13300
#
#      end_price  search_amt
# 0       100.00       0.097
# 1        -1.08      -0.001
# 2        31.92      -0.113
# 3        -9.88      -0.110
# 4        28.75      -0.137
# ..         ...         ...
# 386      33.96         NaN
# 387     -10.00         NaN
# 388      66.54         NaN
# 389     100.00         NaN
# 390      60.24         NaN
#
# [391 rows x 21 columns]

# %%
#total_df.to_csv('final_df.csv')
